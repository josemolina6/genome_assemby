# %% [markdown]
# <a href="https://colab.research.google.com/github/josemolina6/genome_assemby/blob/main/Pipeline_genome_assembly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Módulo de Ensamblaje de genomas**
# Bienvenido al módulo de ensamblaje de genomas usando Google colaboratory (Google colab).
#
# ---
#
#
#
# Material preparado por Dr. Jose Arturo Molina Mora, Ph.D.
#
# Microbiólogo bioinformático
#
# Facultad de Microbiología, Universidad de Costa Rica
#
#
#
# ---
#
#
# **Instrucciones**
#
# 1.) Haga clic en archivo (esquina superior izquierda) y realice una copia en Drive.
#
# *Sus cambios no se guardarán si no realiza este paso.*
#
# 2.) Haga clic en el nombre del libro de trabajo en la esquina superior izquierda y reemplace "Copia de" con su nombre completo
#
# *Enviará el archivo del cuaderno descargado como prueba de finalización de este módulo.*

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/latest/download/Mambaforge-colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:18
# 🔁 Restarting kernel...

# %%
# !conda install -c bioconda entrez-direct
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - entrez-direct
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.12.7  |       ha878542_0         143 KB  conda-forge
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  conda-forge
#     colorama-0.4.6             |     pyhd8ed1ab_0          25 KB  conda-forge
#     conda-22.11.1              |   py38h578d9bd_1         905 KB  conda-forge
#     entrez-direct-16.2         |       he881be0_1         7.5 MB  bioconda
#     gettext-0.21.1             |       h27087fc_0         4.1 MB  conda-forge
#     libidn2-2.3.4              |       h166bdaf_0         157 KB  conda-forge
#     libunistring-0.9.10        |       h7f98852_0         1.4 MB  conda-forge
#     pluggy-1.0.0               |     pyhd8ed1ab_5          16 KB  conda-forge
# ...

# %%
# !conda install -c anaconda libcurl
# !esearch -db nucleotide -query "NC_002516.2" | efetch -format fasta > reference.fasta
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - libcurl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.07.19 |       h06a4308_0         131 KB  anaconda
#     certifi-2022.6.15          |   py38h06a4308_0         156 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         287 KB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates    conda-forge::ca-certificates-2022.12.~ --> anaconda::ca-certificates-2022.07.19-h06a4308_0
#   certifi            conda-forge/noarch::certifi-2022.12.7~ --> anaconda/linux-64::certifi-2022.6.15-py38h06a4308_0
#
#
#
# ...
# certifi-2022.6.15    | 156 KB    | :   0% 0/1 [00:00<?, ?it/s]
# ...

# %%
# Acceso a los datos directamente por link
! wget https://sra-pub-run-odp.s3.amazonaws.com/sra/SRR2037125/SRR2037125
# Out:
# --2023-01-02 15:09:35--  https://sra-pub-run-odp.s3.amazonaws.com/sra/SRR2037125/SRR2037125
# Resolving sra-pub-run-odp.s3.amazonaws.com (sra-pub-run-odp.s3.amazonaws.com)... 52.217.8.68, 52.216.215.57, 52.217.228.73, ...
# Connecting to sra-pub-run-odp.s3.amazonaws.com (sra-pub-run-odp.s3.amazonaws.com)|52.217.8.68|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 146379254 (140M) [application/x-troff-man]
# Saving to: ‘SRR2037125’
#
# SRR2037125          100%[===================>] 139.60M  37.6MB/s    in 4.1s
#
# 2023-01-02 15:09:39 (34.5 MB/s) - ‘SRR2037125’ saved [146379254/146379254]

# %%
# !conda install -c bioconda sra-tools
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - sra-tools
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     cudatoolkit-11.2.2         |      hbe64b41_11       560.3 MB  conda-forge
#     sra-tools-2.9.6            |       hf484d3e_0        45.1 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:       605.4 MB
#
# The following NEW packages will be INSTALLED:
#
#   cudatoolkit        conda-forge/linux-64::cudatoolkit-11.2.2-hbe64b41_11
#   sra-tools          bioconda/linux-64::sra-tools-2.9.6-hf484d3e_0
#
# The following packages will be UPDATED:
#
# ...

# %%
#Si elimina el "./" buscará el acceso en SRA por internet, es decir, no requiere el paso previo
#!fastq-dump SRR2037125 --split-files --gzip --outdir data
# !fastq-dump ./SRR2037125 --split-files --gzip --outdir data
# Out:
# 2023-01-02T15:12:06 fastq-dump.2.9.6 sys: connection failed while opening file within cryptographic module - mbedtls_ssl_handshake returned -9984 ( X509 - Certificate verification failed, e.g. CRL, CA or signature check failed )
# 2023-01-02T15:12:06 fastq-dump.2.9.6 sys: mbedtls_ssl_get_verify_result returned 0x4008 (  !! The certificate is not correctly signed by the trusted CA  !! The certificate is signed with an unacceptable hash.  )
# 2023-01-02T15:12:06 fastq-dump.2.9.6 sys: connection failed while opening file within cryptographic module - ktls_handshake failed while accessing '130.14.29.110' from '172.28.0.12'
# 2023-01-02T15:12:06 fastq-dump.2.9.6 sys: connection failed while opening file within cryptographic module - Failed to create TLS stream for 'www.ncbi.nlm.nih.gov' (130.14.29.110) from '172.28.0.12'
# ...

# %%
# !ls -lh data/
# Out:
# total 170M
# -rw-r--r-- 1 root root 79M Jan  2 15:13 SRR2037125_1.fastq.gz
# -rw-r--r-- 1 root root 91M Jan  2 15:13 SRR2037125_2.fastq.gz

# %%
# !conda install -c bioconda fastqc
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - fastqc
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     alsa-lib-1.2.8             |       h166bdaf_0         578 KB  conda-forge
#     cairo-1.16.0               |    ha61ee94_1014         1.5 MB  conda-forge
#     expat-2.5.0                |       h27087fc_0         189 KB  conda-forge
#     fastqc-0.11.9              |       hdfd78af_1         9.7 MB  bioconda
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       hab24e00_0         1.9 MB  conda-forge
#     fontconfig-2.14.1          |       hc2a2eb6_0         365 KB  conda-forge
# ...

# %%
# !fastqc data/*.fastq.gz -o data/
# Out:
# Started analysis of SRR2037125_1.fastq.gz
# Approx 5% complete for SRR2037125_1.fastq.gz
# Approx 10% complete for SRR2037125_1.fastq.gz
# Approx 15% complete for SRR2037125_1.fastq.gz
# Approx 20% complete for SRR2037125_1.fastq.gz
# Approx 25% complete for SRR2037125_1.fastq.gz
# Approx 30% complete for SRR2037125_1.fastq.gz
# Approx 35% complete for SRR2037125_1.fastq.gz
# Approx 40% complete for SRR2037125_1.fastq.gz
# Approx 45% complete for SRR2037125_1.fastq.gz
# Approx 50% complete for SRR2037125_1.fastq.gz
# Approx 55% complete for SRR2037125_1.fastq.gz
# Approx 60% complete for SRR2037125_1.fastq.gz
# Approx 65% complete for SRR2037125_1.fastq.gz
# Approx 70% complete for SRR2037125_1.fastq.gz
# Approx 75% complete for SRR2037125_1.fastq.gz
# Approx 80% complete for SRR2037125_1.fastq.gz
# Approx 85% complete for SRR2037125_1.fastq.gz
# Approx 90% complete for SRR2037125_1.fastq.gz
# Approx 95% complete for SRR2037125_1.fastq.gz
# ...

# %%
# !conda install -c bioconda trimmomatic
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - trimmomatic
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     trimmomatic-0.39           |       hdfd78af_2         144 KB  bioconda
#     ------------------------------------------------------------
#                                            Total:         144 KB
#
# The following NEW packages will be INSTALLED:
#
#   trimmomatic        bioconda/noarch::trimmomatic-0.39-hdfd78af_2
#
#
#
# ...
#
# done
# done
# done

# %%
! trimmomatic -h
# Out:
# Usage:
#        PE [-version] [-threads <threads>] [-phred33|-phred64] [-trimlog <trimLogFile>] [-summary <statsSummaryFile>] [-quiet] [-validatePairs] [-basein <inputBase> | <inputFile1> <inputFile2>] [-baseout <outputBase> | <outputFile1P> <outputFile1U> <outputFile2P> <outputFile2U>] <trimmer1>...
#    or:
#        SE [-version] [-threads <threads>] [-phred33|-phred64] [-trimlog <trimLogFile>] [-summary <statsSummaryFile>] [-quiet] <inputFile> <outputFile> <trimmer1>...
#    or:
#        -version

# %%
# !trimmomatic PE ./data/SRR2037125_1.fastq.gz ./data/SRR2037125_2.fastq.gz -baseout ./data/SRR2037125-trim.fastq.gz SLIDINGWINDOW:4:20
# Out:
# TrimmomaticPE: Started with arguments:
#  ./data/SRR2037125_1.fastq.gz ./data/SRR2037125_2.fastq.gz -baseout ./data/SRR2037125-trim.fastq.gz SLIDINGWINDOW:4:20
# Multiple cores found: Using 2 threads
# Using templated Output files: ./data/SRR2037125-trim_1P.fastq.gz ./data/SRR2037125-trim_1U.fastq.gz ./data/SRR2037125-trim_2P.fastq.gz ./data/SRR2037125-trim_2U.fastq.gz
# Quality encoding detected as phred33
# Input Read Pairs: 362229 Both Surviving: 356115 (98.31%) Forward Only Surviving: 5891 (1.63%) Reverse Only Surviving: 167 (0.05%) Dropped: 56 (0.02%)
# TrimmomaticPE: Completed successfully

# %%
# !fastqc data/*trim*P.fastq.gz -o data/
# Out:
# Started analysis of SRR2037125-trim_1P.fastq.gz
# Approx 5% complete for SRR2037125-trim_1P.fastq.gz
# Approx 10% complete for SRR2037125-trim_1P.fastq.gz
# Approx 15% complete for SRR2037125-trim_1P.fastq.gz
# Approx 20% complete for SRR2037125-trim_1P.fastq.gz
# Approx 25% complete for SRR2037125-trim_1P.fastq.gz
# Approx 30% complete for SRR2037125-trim_1P.fastq.gz
# Approx 35% complete for SRR2037125-trim_1P.fastq.gz
# Approx 40% complete for SRR2037125-trim_1P.fastq.gz
# Approx 45% complete for SRR2037125-trim_1P.fastq.gz
# Approx 50% complete for SRR2037125-trim_1P.fastq.gz
# Approx 55% complete for SRR2037125-trim_1P.fastq.gz
# Approx 60% complete for SRR2037125-trim_1P.fastq.gz
# Approx 65% complete for SRR2037125-trim_1P.fastq.gz
# Approx 70% complete for SRR2037125-trim_1P.fastq.gz
# Approx 75% complete for SRR2037125-trim_1P.fastq.gz
# Approx 80% complete for SRR2037125-trim_1P.fastq.gz
# Approx 85% complete for SRR2037125-trim_1P.fastq.gz
# ...

# %%
# !conda install -c bioconda megahit
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - megahit
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     megahit-1.2.9              |       h2e03b76_1         2.9 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         2.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   megahit            bioconda/linux-64::megahit-1.2.9-h2e03b76_1
#
#
#
# ...
#
# done
# done
# done

# %%
! megahit -1 ./data/SRR2037125-trim_1P.fastq.gz -2 ./data/SRR2037125-trim_2P.fastq.gz --min-contig-len 1000 -o assembly
# Out:
# 2023-01-02 15:58:05 - MEGAHIT v1.2.9
# 2023-01-02 15:58:05 - Using megahit_core with POPCNT and BMI2 support
# 2023-01-02 15:58:05 - Convert reads to binary library
# 2023-01-02 15:58:10 - b'INFO  sequence/io/sequence_lib.cpp  :   75 - Lib 0 (/content/data/SRR2037125-trim_1P.fastq.gz,/content/data/SRR2037125-trim_2P.fastq.gz): pe, 712230 reads, 301 max length'
# 2023-01-02 15:58:10 - b'INFO  utils/utils.h                 :  152 - Real: 4.0715\tuser: 1.2849\tsys: 0.1733\tmaxrss: 70360'
# 2023-01-02 15:58:10 - k-max reset to: 141
# 2023-01-02 15:58:10 - Start assembly. Number of CPU threads 2
# 2023-01-02 15:58:10 - k list: 21,29,39,59,79,99,119,141
# 2023-01-02 15:58:10 - Memory used: 12254725324
# 2023-01-02 15:58:10 - Extract solid (k+1)-mers for k = 21
# 2023-01-02 15:58:45 - Build graph for k = 21
# 2023-01-02 15:58:52 - Assemble contigs from SdBG for k = 21
# 2023-01-02 15:59:08 - Local assembly for k = 21
# 2023-01-02 15:59:38 - Extract iterative edges from k = 21 to 29
# ...

# %%
! cp assembly/final.contigs.fa final-assembly.fasta

# %%
# !conda install -c bioconda quast
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - quast
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bedtools-2.30.0            |       h468198e_3        15.5 MB  bioconda
#     blast-2.5.0                |       hc0b0e79_3       137.8 MB  bioconda
#     boost-1.80.0               |   py38h4e30db6_4         369 KB  conda-forge
#     boost-cpp-1.80.0           |       h75c5d50_0        17.4 MB  conda-forge
#     brotli-1.0.9               |       h166bdaf_8          18 KB  conda-forge
#     brotli-bin-1.0.9           |       h166bdaf_8          20 KB  conda-forge
#     bwa-0.7.17                 |       h7132678_9         187 KB  bioconda
#     circos-0.69.8              |       hdfd78af_1        26.2 MB  bioconda
#     contourpy-1.0.6            |   py38h43d8883_0         234 KB  conda-forge
# ...

# %%
! quast -h
# Out:
# QUAST: Quality Assessment Tool for Genome Assemblies
# Version: 5.2.0
#
# Usage: python /usr/local/bin/quast [options] <files_with_contigs>
#
# Options:
# -o  --output-dir  <dirname>       Directory to store all result files [default: quast_results/results_<datetime>]
# -r                <filename>      Reference genome file
# -g  --features [type:]<filename>  File with genomic feature coordinates in the reference (GFF, BED, NCBI or TXT)
#                                   Optional 'type' can be specified for extracting only a specific feature type from GFF
# -m  --min-contig  <int>           Lower threshold for contig length [default: 500]
# -t  --threads     <int>           Maximum number of threads [default: 25% of CPUs]
#
# Advanced options:
# -s  --split-scaffolds                 Split assemblies by continuous fragments of N's and add such "contigs" to the comparison
# ...

# %%
! quast -r reference.fasta final-assembly.fasta --gene-finding -o quast-results --plots-format pdf
# Out:
# /usr/local/bin/quast -r reference.fasta final-assembly.fasta --gene-finding -o quast-results --plots-format pdf
#
# Version: 5.2.0
#
# System information:
#   OS: Linux-5.10.133+-x86_64-with-glibc2.10 (linux_64)
#   Python version: 3.8.15
#   CPUs number: 2
#
# Started: 2023-01-02 16:06:50
#
# Logging to /content/quast-results/quast.log
# NOTICE: Maximum number of threads is set to 1 (use --threads option to set it manually)
#
# CWD: /content
# Main parameters:
#   MODE: default, threads: 1, min contig length: 500, min alignment length: 65, min alignment IDY: 95.0, \
#   ambiguity: one, min local misassembly length: 200, min extensive misassembly length: 1000
#
# Reference:
#   /content/reference.fasta ==> reference
#
# Contigs:
#   Pre-processing...
#   final-assembly.fasta ==> final-assembly
#
# 2023-01-02 16:06:51
# Running Basic statistics processor...
#   Reference genome:
#     reference.fasta, length = 6264404, num fragments = 1, GC % = 66.56
#   Contig files:
# ...

# %%
# !conda install -c "bioconda/label/cf201901" prokka
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - prokka
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aragorn-1.2.38             |       h470a237_2         123 KB  bioconda/label/cf201901
#     barrnap-0.9                |                2         555 KB  bioconda/label/cf201901
#     hmmer-3.2.1                |       hfc679d8_0         7.4 MB  bioconda/label/cf201901
#     infernal-1.1.2             |       h470a237_1         7.7 MB  bioconda/label/cf201901
#     libgcc-7.2.0               |       h69d50b8_2         304 KB  conda-forge
#     libidn11-1.34              |       h1cef754_0         227 KB  conda-forge
#     minced-0.3.2               |                0          30 KB  bioconda/label/cf201901
#     parallel-20160622          |                1        1019 KB  bioconda/label/cf201901
# ...

# %%
! ls /usr/local/lib/perl5/site_perl/5.22.0/
# Out:
# Algorithm  Class  Exception  Test  URI.pm
# Bio	   Data   IO	     Text  x86_64-linux-thread-multi
# Capture    Devel  Sub	     URI   XML

# %%
# !prokka --help
# Out:
# Can't locate XML/Simple.pm in @INC (you may need to install the XML::Simple module) (@INC contains: /usr/local/lib/perl5/5.32/site_perl /usr/local/lib/perl5/site_perl /usr/local/lib/perl5/5.32/vendor_perl /usr/local/lib/perl5/vendor_perl /usr/local/lib/perl5/5.32/core_perl /usr/local/lib/perl5/core_perl .) at /usr/local/bin/prokka line 25.
# BEGIN failed--compilation aborted at /usr/local/bin/prokka line 25.

# %% [markdown]
# # **Módulo de Alineamineto múltiple y filogenia**
# Bienvenido al módulo de Alineamineto múltiple y filogenia usando Google colaboratory (Google colab).
#
# ---
#
#
#
# Material preparado por Dr. Jose Arturo Molina Mora, Ph.D.
#
# Microbiólogo bioinformático
#
# Facultad de Microbiología, Universidad de Costa Rica
#
#
#
# ---
#
#
# **Instrucciones**
#
# 1.) Haga clic en archivo (esquina superior izquierda) y realice una copia en Drive.
#
# *Sus cambios no se guardarán si no realiza este paso.*
#
# 2.) Haga clic en el nombre del libro de trabajo en la esquina superior izquierda y reemplace "Copia de" con su nombre completo
#
# *Enviará el archivo del cuaderno descargado como prueba de finalización de este módulo.*

# %%
# !conda install -c bioconda mafft
#! conda install -c "bioconda/label/cf201901" mafft
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - mafft
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     mafft-7.508                |       hec16e2b_0         3.1 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         3.1 MB
#
# The following NEW packages will be INSTALLED:
#
#   mafft              bioconda/linux-64::mafft-7.508-hec16e2b_0
#
#
#
# ...
#
# done
# done
# done

# %%
! mafft SecuenciasEBOLAvirus.fas > alineamiento.fasta
# Out:
# nthread = 0
# nthreadpair = 0
# nthreadtb = 0
# ppenalty_ex = 0
# stacksize: 8192 kb
# generating a scoring matrix for nucleotide (dist=200) ... done
# Gap Penalty = -1.53, +0.00, +0.00
#
#
#
# Making a distance matrix ..
#     1 / 10
# done.
#
# Constructing a UPGMA tree (efffree=0) ...
#     0 / 10
# done.
#
# Progressive alignment 1/2...
# STEP     7 / 9  f
# Reallocating..done. *alloclen = 39705
# STEP     9 / 9  f
# done.
#
# Making a distance matrix from msa..
#     0 / 10
# done.
#
# Constructing a UPGMA tree (efffree=1) ...
#     0 / 10
# done.
#
# Progressive alignment 2/2...
# STEP     6 / 9  f
# Reallocating..done. *alloclen = 39121
# STEP     8 / 9  f
# Reallocating..done. *alloclen = 40574
# STEP     9 / 9  f
# done.
#
# disttbfast (nuc) Version 7.508
# alg=A, model=DNA200 (2), 1.53 (4.59), -0.00 (-0.00), noshift, amax=0.0
# 0 thread(s)
#
#
# Strategy:
#  FFT-NS-2 (Fast but rough)
#  Progressive method (guide trees were built 2 times.)
#
# ...

# %%
# !conda install -c bioconda iqtree
# Out:
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - iqtree
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     iqtree-2.2.0.3             |       hb97b32f_1         6.9 MB  bioconda
#     ------------------------------------------------------------
#                                            Total:         6.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   iqtree             bioconda/linux-64::iqtree-2.2.0.3-hb97b32f_1
#
#
#
# ...
#
# done
# done
# done

# %%
! iqtree -s alineamiento.fasta
# Out:
# IQ-TREE multicore version 2.2.0.3 COVID-edition for Linux 64-bit built Aug  2 2022
# Developed by Bui Quang Minh, James Barbetti, Nguyen Lam Tung,
# Olga Chernomor, Heiko Schmidt, Dominik Schrempf, Michael Woodhams, Ly Trong Nhan.
#
# Host:    25d811c64391 (AVX2, FMA3, 12 GB RAM)
# Command: iqtree -s alineamiento.fasta
# Seed:    212857 (Using SPRNG - Scalable Parallel Random Number Generator)
# Time:    Mon Jan  2 16:15:01 2023
# Kernel:  AVX+FMA - 1 threads (2 CPU cores detected)
#
# HINT: Use -nt option to specify number of threads because your CPU has 2 cores!
# HINT: -nt AUTO will automatically determine the best number of threads to use.
#
# Reading alignment file alineamiento.fasta ... Fasta format detected
# Reading fasta file: done in 0.00375447 secs using 95.97% CPU
# Alignment most likely contains DNA/RNA sequences
# Constructing alignment: done in 0.016186 secs using 32.03% CPU
# Alignment has 10 sequences with 20839 columns, 3478 distinct patterns
# ...
